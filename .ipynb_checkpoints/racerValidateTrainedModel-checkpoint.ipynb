# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import *


from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
# load the pretrained model from file
model = tf.keras.models.load_model('racerModel_210722.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
X = np.load('trackTrainImages_210624.npy')
y = np.load('trackPos_210624.npy')



print(X.shape)
print(y.shape)
# Out:
# (380, 224, 224, 3)
# (380,)

# %%
# convert from integers to floats
X = X.astype('float32')

# normalize to range 0-1
X = X / 255.0

# %%
y_pred = model.predict(X)

# %%
for i in range(len(y)):
    
    print('Actual : '+ str(y[i])+' -- Pres : '+str(y_pred[i]))
# Out:
# Actual : 116.0 -- Pres : [111.91512]
# Actual : 116.0 -- Pres : [112.70476]
# Actual : 119.0 -- Pres : [111.93253]
# Actual : 119.1 -- Pres : [113.89398]
# Actual : 118.0 -- Pres : [111.07319]
# Actual : 118.3 -- Pres : [113.64585]
# Actual : 118.3 -- Pres : [109.79511]
# Actual : 118.3 -- Pres : [112.43318]
# Actual : 118.3 -- Pres : [115.217]
# Actual : 118.3 -- Pres : [116.64171]
# Actual : 118.3 -- Pres : [120.40704]
# Actual : 118.3 -- Pres : [122.19751]
# Actual : 118.3 -- Pres : [129.32509]
# Actual : 118.3 -- Pres : [120.49297]
# Actual : 118.3 -- Pres : [129.8782]
# Actual : 118.3 -- Pres : [119.57664]
# Actual : 118.3 -- Pres : [111.68711]
# Actual : 118.3 -- Pres : [120.46935]
# Actual : 118.3 -- Pres : [120.45907]
# Actual : 118.3 -- Pres : [116.429054]
# Actual : 118.3 -- Pres : [112.983864]
# Actual : 118.3 -- Pres : [118.82025]
# Actual : 118.3 -- Pres : [121.27104]
# Actual : 118.3 -- Pres : [119.32471]
# Actual : 118.3 -- Pres : [128.71143]
# Actual : 118.3 -- Pres : [126.60893]
# Actual : 118.3 -- Pres : [112.00229]
# Actual : 118.3 -- Pres : [115.65426]
# Actual : 118.3 -- Pres : [116.45441]
# Actual : 118.3 -- Pres : [117.06284]
# Actual : 118.3 -- Pres : [123.047714]
# Actual : 118.3 -- Pres : [121.85104]
# Actual : 118.3 -- Pres : [119.25601]
# Actual : 118.3 -- Pres : [111.66286]
# Actual : 118.3 -- Pres : [117.94125]
# Actual : 118.3 -- Pres : [127.95978]
# Actual : 118.3 -- Pres : [127.46138]
# Actual : 118.3 -- Pres : [129.03973]
# Actual : 118.3 -- Pres : [128.08794]
# Actual : 118.3 -- Pres : [130.15709]
# Actual : 118.3 -- Pres : [129.34045]
# Actual : 118.3 -- Pres : [127.96232]
# Actual : 118.3 -- Pres : [118.69649]
# Actual : 118.3 -- Pres : [119.96394]
# Actual : 118.3 -- Pres : [126.73579]
# Actual : 118.3 -- Pres : [123.17336]
# Actual : 118.3 -- Pres : [122.43768]
# Actual : 118.3 -- Pres : [118.80379]
# Actual : 118.3 -- Pres : [116.46396]
# Actual : 118.3 -- Pres : [115.866]
# Actual : 118.3 -- Pres : [111.353195]
# Actual : 116.0 -- Pres : [110.64539]
# Actual : 112.0 -- Pres : [111.61948]
# Actual : 112.8 -- Pres : [106.068375]
# Actual : 112.8 -- Pres : [103.74958]
# Actual : 114.0 -- Pres : [116.6649]
# Actual : 118.0 -- Pres : [118.47297]
# Actual : 126.0 -- Pres : [131.88737]
# Actual : 144.0 -- Pres : [134.52725]
# Actual : 143.0 -- Pres : [132.63927]
# Actual : 137.0 -- Pres : [132.86095]
# Actual : 132.0 -- Pres : [127.279564]
# Actual : 115.0 -- Pres : [125.30085]
# Actual : 110.0 -- Pres : [125.38602]
# Actual : 112.0 -- Pres : [117.47638]
# Actual : 104.0 -- Pres : [97.374176]
# Actual : 104.0 -- Pres : [117.63492]
# Actual : 100.0 -- Pres : [103.12912]
# Actual : 104.0 -- Pres : [92.38146]
# Actual : 122.0 -- Pres : [118.246414]
# Actual : 138.0 -- Pres : [132.14955]
# Actual : 147.0 -- Pres : [128.87769]
# Actual : 154.0 -- Pres : [130.81989]
# Actual : 165.0 -- Pres : [142.46474]
# Actual : 168.0 -- Pres : [163.82584]
# Actual : 170.0 -- Pres : [160.31975]
# Actual : 157.0 -- Pres : [149.08907]
# Actual : 142.0 -- Pres : [140.53079]
# Actual : 127.0 -- Pres : [127.59538]
# Actual : 104.0 -- Pres : [116.53769]
# Actual : 81.0 -- Pres : [104.56981]
# Actual : 84.0 -- Pres : [98.16255]
# Actual : 85.0 -- Pres : [107.75301]
# Actual : 97.0 -- Pres : [96.28374]
# Actual : 106.0 -- Pres : [102.314926]
# Actual : 126.0 -- Pres : [117.29743]
# Actual : 139.0 -- Pres : [138.37373]
# Actual : 145.0 -- Pres : [115.31051]
# Actual : 146.0 -- Pres : [115.63851]
# Actual : 152.0 -- Pres : [153.322]
# Actual : 154.0 -- Pres : [119.04592]
# Actual : 130.0 -- Pres : [101.59421]
# Actual : 100.0 -- Pres : [109.27509]
# Actual : 94.0 -- Pres : [104.95887]
# Actual : 89.0 -- Pres : [81.03029]
# Actual : 80.0 -- Pres : [80.635796]
# Actual : 69.0 -- Pres : [74.37825]
# Actual : 69.6 -- Pres : [66.332275]
# Actual : 70.0 -- Pres : [70.46167]
# Actual : 84.0 -- Pres : [110.24876]
# Actual : 116.0 -- Pres : [121.61622]
# Actual : 131.0 -- Pres : [124.96158]
# Actual : 138.0 -- Pres : [130.03781]
# Actual : 144.0 -- Pres : [144.9753]
# Actual : 146.0 -- Pres : [121.883354]
# Actual : 139.0 -- Pres : [94.84521]
# Actual : 116.0 -- Pres : [78.418015]
# Actual : 113.0 -- Pres : [124.522606]
# Actual : 115.0 -- Pres : [110.21031]
# Actual : 120.0 -- Pres : [124.1909]
# Actual : 117.0 -- Pres : [97.26478]
# Actual : 96.0 -- Pres : [105.822136]
# Actual : 81.0 -- Pres : [83.52997]
# Actual : 82.0 -- Pres : [90.819374]
# Actual : 83.0 -- Pres : [95.74427]
# Actual : 112.0 -- Pres : [116.39954]
# Actual : 123.0 -- Pres : [112.53226]
# Actual : 127.0 -- Pres : [127.685265]
# Actual : 124.0 -- Pres : [120.784996]
# Actual : 110.0 -- Pres : [123.6895]
# Actual : 104.0 -- Pres : [103.41985]
# Actual : 114.0 -- Pres : [118.190125]
# Actual : 105.0 -- Pres : [95.45564]
# Actual : 95.0 -- Pres : [98.53377]
# Actual : 82.0 -- Pres : [88.74713]
# Actual : 47.0 -- Pres : [47.947052]
# Actual : 26.0 -- Pres : [68.64346]
# Actual : 4.0 -- Pres : [4.307062]
# Actual : 0.0 -- Pres : [37.72927]
# Actual : 0.0 -- Pres : [0.6144075]
# Actual : 0.0 -- Pres : [41.344612]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [36.808838]
# Actual : 0.0 -- Pres : [40.141186]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [0.04223538]
# Actual : 157.0 -- Pres : [94.76249]
# Actual : 197.0 -- Pres : [195.09871]
# Actual : 219.0 -- Pres : [225.0912]
# Actual : 219.5 -- Pres : [119.61312]
# Actual : 219.5 -- Pres : [209.90028]
# Actual : 219.5 -- Pres : [238.60474]
# Actual : 219.5 -- Pres : [232.26375]
# Actual : 219.5 -- Pres : [233.5797]
# Actual : 219.5 -- Pres : [223.76982]
# Actual : 219.5 -- Pres : [215.12102]
# Actual : 219.5 -- Pres : [186.02919]
# Actual : 219.5 -- Pres : [193.94405]
# Actual : 219.5 -- Pres : [236.9052]
# Actual : 219.5 -- Pres : [184.9164]
# Actual : 219.5 -- Pres : [226.18805]
# Actual : 219.5 -- Pres : [239.99603]
# Actual : 219.5 -- Pres : [220.11221]
# Actual : 219.5 -- Pres : [208.18053]
# Actual : 219.5 -- Pres : [176.83919]
# Actual : 219.5 -- Pres : [181.27559]
# Actual : 219.5 -- Pres : [232.8476]
# Actual : 219.5 -- Pres : [237.50026]
# Actual : 219.5 -- Pres : [142.0082]
# Actual : 219.5 -- Pres : [136.60094]
# Actual : 219.5 -- Pres : [131.28719]
# Actual : 219.5 -- Pres : [208.32277]
# Actual : 219.5 -- Pres : [223.40001]
# Actual : 184.0 -- Pres : [195.77937]
# Actual : 147.0 -- Pres : [99.66447]
# Actual : 147.4 -- Pres : [157.26758]
# Actual : 79.0 -- Pres : [81.3841]
# Actual : 58.0 -- Pres : [57.138268]
# Actual : 46.0 -- Pres : [46.848915]
# Actual : 44.0 -- Pres : [46.93096]
# Actual : 46.0 -- Pres : [55.918186]
# Actual : 51.0 -- Pres : [84.72737]
# Actual : 53.0 -- Pres : [76.0831]
# Actual : 62.0 -- Pres : [65.080765]
# Actual : 67.0 -- Pres : [63.049828]
# Actual : 69.0 -- Pres : [68.45807]
# Actual : 65.0 -- Pres : [68.879326]
# Actual : 60.0 -- Pres : [67.62897]
# Actual : 54.0 -- Pres : [59.824203]
# Actual : 42.0 -- Pres : [44.550476]
# Actual : 37.0 -- Pres : [38.126923]
# Actual : 40.0 -- Pres : [42.66901]
# Actual : 37.0 -- Pres : [42.29893]
# Actual : 37.8 -- Pres : [30.300034]
# Actual : 34.0 -- Pres : [31.12606]
# Actual : 28.0 -- Pres : [49.809113]
# Actual : 26.0 -- Pres : [52.286377]
# Actual : 22.0 -- Pres : [58.568565]
# Actual : 18.0 -- Pres : [72.482254]
# Actual : 16.0 -- Pres : [62.15954]
# Actual : 16.0 -- Pres : [12.966716]
# Actual : 27.0 -- Pres : [29.651833]
# Actual : 42.0 -- Pres : [124.100174]
# Actual : 73.0 -- Pres : [70.906395]
# Actual : 99.0 -- Pres : [94.90173]
# Actual : 108.0 -- Pres : [103.701164]
# Actual : 123.0 -- Pres : [117.79186]
# Actual : 131.0 -- Pres : [128.81361]
# Actual : 128.0 -- Pres : [132.50194]
# Actual : 119.0 -- Pres : [105.9446]
# Actual : 108.0 -- Pres : [103.28129]
# Actual : 99.0 -- Pres : [96.77669]
# Actual : 90.0 -- Pres : [86.90997]
# Actual : 68.0 -- Pres : [56.734035]
# Actual : 56.0 -- Pres : [59.684055]
# Actual : 46.0 -- Pres : [73.878716]
# Actual : 48.0 -- Pres : [64.11808]
# Actual : 51.0 -- Pres : [56.44158]
# Actual : 46.0 -- Pres : [59.817924]
# Actual : 49.0 -- Pres : [52.109795]
# Actual : 61.0 -- Pres : [66.258896]
# Actual : 59.0 -- Pres : [61.730316]
# Actual : 61.0 -- Pres : [67.161514]
# Actual : 66.0 -- Pres : [71.233765]
# Actual : 71.0 -- Pres : [76.90603]
# Actual : 75.0 -- Pres : [82.64329]
# Actual : 78.0 -- Pres : [83.635735]
# Actual : 84.0 -- Pres : [84.64193]
# Actual : 79.0 -- Pres : [79.90741]
# Actual : 75.0 -- Pres : [72.1735]
# Actual : 72.0 -- Pres : [68.18638]
# Actual : 66.0 -- Pres : [65.080414]
# Actual : 59.0 -- Pres : [61.222076]
# Actual : 49.0 -- Pres : [53.492043]
# Actual : 44.0 -- Pres : [51.347008]
# Actual : 38.0 -- Pres : [59.782326]
# Actual : 44.0 -- Pres : [49.532703]
# Actual : 49.0 -- Pres : [63.25776]
# Actual : 42.0 -- Pres : [66.98083]
# Actual : 46.0 -- Pres : [50.15618]
# Actual : 53.0 -- Pres : [88.66392]
# Actual : 62.0 -- Pres : [60.643345]
# Actual : 74.0 -- Pres : [115.39842]
# Actual : 88.0 -- Pres : [98.677216]
# Actual : 100.0 -- Pres : [86.480415]
# Actual : 102.0 -- Pres : [108.87926]
# Actual : 92.0 -- Pres : [70.42694]
# Actual : 76.0 -- Pres : [65.0584]
# Actual : 64.0 -- Pres : [64.39975]
# Actual : 33.0 -- Pres : [82.14962]
# Actual : 10.0 -- Pres : [75.548836]
# Actual : 0.0 -- Pres : [60.154835]
# Actual : 0.0 -- Pres : [37.462296]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [26.485626]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 0.0 -- Pres : [0.00736927]
# Actual : 12.0 -- Pres : [28.780714]
# Actual : 20.0 -- Pres : [26.077143]
# Actual : 15.0 -- Pres : [5.1232295]
# Actual : 15.0 -- Pres : [12.537684]
# Actual : 14.0 -- Pres : [13.64091]
# Actual : 7.0 -- Pres : [5.767873]
# Actual : 4.0 -- Pres : [0.00736927]
# Actual : 4.1 -- Pres : [19.73222]
# Actual : 4.1 -- Pres : [38.592903]
# Actual : 0.0 -- Pres : [54.641117]
# Actual : 0.0 -- Pres : [70.13508]
# Actual : 0.0 -- Pres : [77.589874]
# Actual : 0.0 -- Pres : [82.205574]
# Actual : 0.0 -- Pres : [78.96112]
# Actual : 0.0 -- Pres : [51.30534]
# Actual : 0.0 -- Pres : [50.929447]
# Actual : 29.0 -- Pres : [68.71027]
# Actual : 47.0 -- Pres : [46.053535]
# Actual : 81.0 -- Pres : [84.51201]
# Actual : 111.0 -- Pres : [120.98941]
# Actual : 121.0 -- Pres : [131.79909]
# Actual : 124.0 -- Pres : [121.116425]
# Actual : 118.0 -- Pres : [120.55036]
# Actual : 107.0 -- Pres : [103.04509]
# Actual : 94.0 -- Pres : [91.89818]
# Actual : 87.0 -- Pres : [91.367935]
# Actual : 80.0 -- Pres : [86.556915]
# Actual : 83.0 -- Pres : [76.29537]
# Actual : 80.0 -- Pres : [82.63841]
# Actual : 79.0 -- Pres : [93.2233]
# Actual : 80.0 -- Pres : [121.42513]
# Actual : 96.0 -- Pres : [91.35903]
# Actual : 112.0 -- Pres : [117.22657]
# Actual : 128.0 -- Pres : [130.02818]
# Actual : 166.0 -- Pres : [159.08273]
# Actual : 197.0 -- Pres : [162.24922]
# Actual : 225.0 -- Pres : [233.01013]
# Actual : 225.0 -- Pres : [224.37096]
# Actual : 225.0 -- Pres : [221.44844]
# Actual : 225.0 -- Pres : [248.81642]
# Actual : 225.0 -- Pres : [214.3194]
# Actual : 218.0 -- Pres : [218.78825]
# Actual : 196.0 -- Pres : [148.9257]
# Actual : 178.0 -- Pres : [141.57953]
# Actual : 153.0 -- Pres : [160.32617]
# Actual : 136.0 -- Pres : [140.93631]
# Actual : 124.0 -- Pres : [121.33603]
# Actual : 126.0 -- Pres : [131.65305]
# Actual : 137.0 -- Pres : [128.4883]
# Actual : 147.0 -- Pres : [138.4436]
# Actual : 157.0 -- Pres : [146.66109]
# Actual : 184.0 -- Pres : [165.6584]
# Actual : 206.0 -- Pres : [193.73848]
# Actual : 217.0 -- Pres : [145.0722]
# Actual : 217.0 -- Pres : [152.56953]
# Actual : 200.0 -- Pres : [182.02882]
# Actual : 190.0 -- Pres : [158.27681]
# Actual : 169.0 -- Pres : [147.88994]
# Actual : 140.0 -- Pres : [114.40202]
# Actual : 108.0 -- Pres : [114.0713]
# Actual : 98.0 -- Pres : [106.69436]
# Actual : 101.0 -- Pres : [109.41081]
# Actual : 92.0 -- Pres : [108.34208]
# Actual : 95.0 -- Pres : [102.25774]
# Actual : 101.0 -- Pres : [94.73914]
# Actual : 105.0 -- Pres : [97.08487]
# Actual : 111.0 -- Pres : [99.98676]
# Actual : 106.0 -- Pres : [83.94403]
# Actual : 107.0 -- Pres : [99.02754]
# Actual : 100.0 -- Pres : [102.17001]
# Actual : 102.0 -- Pres : [109.912605]
# Actual : 105.0 -- Pres : [98.67421]
# Actual : 95.0 -- Pres : [106.1494]
# Actual : 86.0 -- Pres : [94.2506]
# Actual : 97.0 -- Pres : [103.252716]
# Actual : 104.0 -- Pres : [106.10386]
# Actual : 113.0 -- Pres : [122.69834]
# Actual : 130.0 -- Pres : [134.91917]
# Actual : 132.0 -- Pres : [136.57112]
# Actual : 135.0 -- Pres : [150.1844]
# Actual : 129.0 -- Pres : [112.98244]
# Actual : 122.0 -- Pres : [124.93227]
# Actual : 104.0 -- Pres : [109.940674]
# Actual : 87.0 -- Pres : [87.34394]
# Actual : 72.0 -- Pres : [84.24513]
# Actual : 75.0 -- Pres : [85.19042]
# Actual : 81.0 -- Pres : [84.82556]
# Actual : 97.0 -- Pres : [89.525986]
# Actual : 98.0 -- Pres : [94.83362]
# Actual : 101.0 -- Pres : [114.63019]
# Actual : 103.0 -- Pres : [118.16724]
# Actual : 112.0 -- Pres : [129.4776]
# Actual : 117.0 -- Pres : [129.22707]
# Actual : 155.0 -- Pres : [131.61446]
# Actual : 176.0 -- Pres : [122.32831]
# Actual : 192.0 -- Pres : [108.27903]
# Actual : 200.0 -- Pres : [113.97915]
# Actual : 196.0 -- Pres : [126.508286]
# Actual : 193.0 -- Pres : [160.85512]
# Actual : 188.0 -- Pres : [171.23994]
# Actual : 186.0 -- Pres : [134.46281]
# Actual : 189.0 -- Pres : [199.78732]
# Actual : 185.0 -- Pres : [179.46754]
# Actual : 181.0 -- Pres : [176.68744]
# Actual : 167.0 -- Pres : [165.45085]
# Actual : 151.0 -- Pres : [147.14677]
# Actual : 133.0 -- Pres : [140.1745]
# Actual : 101.0 -- Pres : [102.899254]
# Actual : 67.0 -- Pres : [22.128178]
# Actual : 43.0 -- Pres : [31.110088]
# Actual : 31.0 -- Pres : [36.40937]
# Actual : 30.0 -- Pres : [31.20034]
# Actual : 33.0 -- Pres : [38.85836]
# Actual : 40.0 -- Pres : [72.39406]
# Actual : 56.0 -- Pres : [77.278366]
# Actual : 54.0 -- Pres : [53.81806]
# Actual : 57.0 -- Pres : [67.79702]
# Actual : 57.0 -- Pres : [58.808254]
# Actual : 52.0 -- Pres : [51.42243]
# Actual : 56.0 -- Pres : [61.75087]
# Actual : 189.0 -- Pres : [145.0994]
# Actual : 207.0 -- Pres : [209.649]
# Actual : 208.0 -- Pres : [212.06499]
# Actual : 208.9 -- Pres : [175.70117]
# Actual : 208.9 -- Pres : [178.03539]
# Actual : 208.9 -- Pres : [223.59685]
# Actual : 208.9 -- Pres : [130.05272]
# Actual : 208.9 -- Pres : [133.67566]
# Actual : 189.0 -- Pres : [178.37779]
# Actual : 156.0 -- Pres : [102.9385]
