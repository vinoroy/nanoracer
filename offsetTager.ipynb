# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import ipywidgets as widgets

#%matplotlib inline

# %%
images = np.load('trackImages.npy')

# %%
# %matplotlib tk

offsets = []

b = widgets.Button(
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)


fig = plt.figure()
imgplot = plt.imshow(images[0])

w = widgets.HTML("Event information appears here when you click on the figure")


class ButtonCounter:
    
    def __init__(self):
    
        self.counter = 0
        
    def click(self,button):
        
        
        self.counter = self.counter + 1
        
        button.description = str(self.counter)
        
        imgplot = plt.imshow(images[self.counter])
    
    
c = ButtonCounter()


def onclick(event):
    w.value = 'button=%d, x=%d, y=%d, xdata=%f, ydata=%f'%(
              event.button, event.x, event.y, event.xdata, event.ydata)
    
    w.value = 'ok'
    
    print('ok')
    
    offsets.append([c.counter,event.x])


b.on_click(c.click)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
display(w,b)
# Out:
# HTML(value='Event information appears here when you click on the figure')
# Button(description='Click me', icon='check', style=ButtonStyle(), tooltip='Click me')

# %%
offsets
# Out:
# []
